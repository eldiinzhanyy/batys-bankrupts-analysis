# %% [markdown]
# <a href="https://colab.research.google.com/github/eldiinzhanyy/batys-bankrupts-analysis/blob/main/bezrabotica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-70dd7fcb-6537-4577-a64c-d727b90f3fb9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70dd7fcb-6537-4577-a64c-d727b90f3fb9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel("Т-14-23-Г_рус.xls", sheet_name="13", header=None)

# %%
df.head()
# Out:
#                                                   0                      1   \
# 0  13. Основные индикаторы рынка труда по районам...                    NaN
# 1                                                NaN  Рабочая сила, человек
# 2                                                NaN                    NaN
# 3                                      Все население                    NaN
# 4                      Западно-Казахстанская область                 357116
#
#                                                   2   \
# 0                                                NaN
# 1  Доля рабочей силы в численности населения, в п...
# 2                                                NaN
# 3                                                NaN
# 4                                                 70
#
#                            3                   4   \
# 0                         NaN                 NaN
# 1  Занятое население, человек         В том числе
# ...

# %%
df = pd.read_excel("Т-14-23-Г_рус.xls", sheet_name="13", skiprows=3, header=None)

# %%
df.head()
# Out:
#                               0         1     2         3         4        5   \
# 0                  Все население       NaN   NaN       NaN       NaN      NaN
# 1  Западно-Казахстанская область  357116.0  70.0  340153.0  251209.0  88944.0
# 2                   Уральск г.а.  179022.0  66.3  170751.0  140406.0  30345.0
# 3              Акжаикский район    18959.0  75.1   18069.0   10911.0   7158.0
# 4              Бурлинский район    32320.0  76.0   30889.0   26120.0   4769.0
#
#         6    7    8         9     10
# 0      NaN  NaN  NaN       NaN   NaN
# 1  16963.0  4.7  3.6  153305.0  30.0
# 2   8271.0  4.6  3.4   91170.0  33.7
# 3    890.0  4.7  4.2    6298.0  24.9
# 4   1431.0  4.4  3.5   10212.0  24.0

# %%
df.columns = ["район", "рабочая_сила", "доля_рабочей_силы", "занятое_население", "наемные_работники", "самозанятые", "безработное_население",  "уровень_безработицы", "уровень_молодежной_безработицы", "вне_рабочей_силы", "доля_вне_рабочей_силы"]

# %%
df.head()
# Out:
#                            район  рабочая_сила  доля_рабочей_силы  \
# 0                  Все население           NaN                NaN
# 1  Западно-Казахстанская область      357116.0               70.0
# 2                   Уральск г.а.      179022.0               66.3
# 3              Акжаикский район        18959.0               75.1
# 4              Бурлинский район        32320.0               76.0
#
#    занятое_население  наемные_работники  самозанятые  безработное_население  \
# 0                NaN                NaN          NaN                    NaN
# 1           340153.0           251209.0      88944.0                16963.0
# 2           170751.0           140406.0      30345.0                 8271.0
# 3            18069.0            10911.0       7158.0                  890.0
# 4            30889.0            26120.0       4769.0                 1431.0
#
#    уровень_безработицы уровень_молодежной_безработицы  вне_рабочей_силы  \
# ...

# %%
df.head(15)
# Out:
#                             район  рабочая_сила  доля_рабочей_силы  \
# 0                   Все население           NaN                NaN
# 1   Западно-Казахстанская область      357116.0               70.0
# 2                    Уральск г.а.      179022.0               66.3
# 3               Акжаикский район        18959.0               75.1
# 4               Бурлинский район        32320.0               76.0
# 5             Жангалинский район        10881.0               72.7
# 6              Жанибекский район         7766.0               76.3
# 7                  Район Бәйтерек       34933.0               73.9
# 8             Казталовский район        13498.0               72.0
# 9             Каратобинский район        6846.0               72.8
# 10           Бокейординский район        7351.0               73.5
# 11                Сырымский район        9110.0               76.9
# 12            Таскалинский район         8685.0               73.2
# ...

# %%
df = df.iloc[1:15]

# %%
df.tail()
# Out:
#                    район  рабочая_сила  доля_рабочей_силы  занятое_население  \
# 10  Бокейординский район        7351.0               73.5             6939.0
# 11       Сырымский район        9110.0               76.9             8669.0
# 12   Таскалинский район         8685.0               73.2             8260.0
# 13    Теректинский район       21016.0               72.4            20013.0
# 14  Чингирлауский район         6729.0               73.5             6398.0
#
#     наемные_работники  самозанятые  безработное_население  \
# 10             3582.0       3357.0                  412.0
# 11             4687.0       3982.0                  441.0
# 12             5251.0       3009.0                  425.0
# 13            14848.0       5165.0                 1003.0
# 14             4244.0       2154.0                  331.0
#
#     уровень_безработицы уровень_молодежной_безработицы  вне_рабочей_силы  \
# 10                  5.6                            4.7            2651.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 1 to 14
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   район                           14 non-null     object
#  1   рабочая_сила                    14 non-null     float64
#  2   доля_рабочей_силы               14 non-null     float64
#  3   занятое_население               14 non-null     float64
#  4   наемные_работники               14 non-null     float64
#  5   самозанятые                     14 non-null     float64
#  6   безработное_население           14 non-null     float64
#  7   уровень_безработицы             14 non-null     float64
#  8   уровень_молодежной_безработицы  14 non-null     object
#  9   вне_рабочей_силы                14 non-null     float64
#  10  доля_вне_рабочей_силы           14 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 1.3+ KB

# %%
df["уровень_молодежной_безработицы"]
# Out:
# 1     3.6
# 2     3.4
# 3     4.2
# 4     3.5
# 5     3.7
# 6     4.3
# 7     2.9
# 8     4.2
# 9       6
# 10    4.7
# 11    3.4
# 12    4.3
# 13    4.1
# 14    4.4
# Name: уровень_молодежной_безработицы, dtype: object

# %%
df["уровень_молодежной_безработицы"] = pd.to_numeric(df["уровень_молодежной_безработицы"], errors="coerce")

# %%
df["уровень_молодежной_безработицы"].dtype
# Out:
# dtype('float64')

# %%
df["уровень_молодежной_безработицы"].isna().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("unemployment_zko_clean.csv", index=False, encoding="utf-8-sig")
